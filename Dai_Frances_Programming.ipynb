# %% [markdown]
# # HW 1 - Programming
# ## Frances Dai
# ## fad4yr
# ## Feb 1, 2024

# %% [markdown]
# ### Q1

# %% [markdown]
# 1a. I studied 8 jobs that interest me: Data Scientist, Graphic Designer, Software Developer, Web Designer, Special Effects Animators, Art Directors, Information Security Analysts, and Computer and Information System Manager
#
# 1b. One thing I found surprising about my findings is that the median pay for art directors is higher than I would've thought (105,180).
#
# 1c. Ranking of jobs from best to worst: Art Director, Software Developer, Special Effects Animator, Computer and Information System Manager, Web Designer, Graphic Designer, Data Scientist, Information Security Analyst. I ranked these based on how much I would personally love to have these jobs!

# %% [markdown]
# ### Q2

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 1, 50)
y = np.log(x)
z = np.exp(x)
plt.scatter(x, y)
plt.scatter(x, z)
plt.show()

plt.scatter(x, y, label = "Natural Log")
plt.scatter(x, z, label = "Exponential" )
plt.xlabel("x")
plt.ylabel("y")
plt.title("Natural Log and exponent functions")
plt.legend(loc = "lower right")
plt.show()

a = np.linspace(-6.5, 6.5, 100)
s = np.sin(a)
c = np.cos(a)
plt.scatter(a, s)
plt.scatter(a, c)
plt.show()

plt.plot(a, s, label = "Sine")
plt.plot(a, c, label = "Cosine")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Sine and Cosine Functions")
plt.legend(loc = "lower left")
plt.show()
# Out:
# /var/folders/9r/mbbq5cd95_v_3txywt5j_v1c0000gn/T/ipykernel_99872/1914110094.py:5: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x)
